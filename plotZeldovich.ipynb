# %%
import numpy as N
import zeldovich as Z
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
plt.style.use('nuala')

# %%
pkfile='/Users/nuala/Documents/MATLAB/simanalysis/pk_indra7313.txt'

# %%
pkinit=N.loadtxt(pkfile)

# %%
plt.loglog(pkinit[:,0], pkinit[:,1]*N.exp(-pkinit[:,0]**2*0.0**2))
plt.loglog(pkinit[:,0], pkinit[:,1])
plt.ylim([10**-2, 10**5])
plt.xlabel('k [h/Mpc]')
plt.ylabel('P(k)')

# %%
reload(Z)
dens0, x, y, z=Z.run(0.0, pkinit, boxsize=200, ngrid=128, nparticles=128, exactpk=True)

# %%
plt.pcolor(dens0[:,:,0])
plt.colorbar()

# %%
plt.subplot(111, aspect=1)
subset=N.where((x<200) & (y<200) & (z<5))
plt.scatter(y[subset], x[subset], lw=0, s=3)
plt.xlim([0, 40])
plt.ylim([0, 40])
plt.xlabel('x [Mpc/h]')
plt.ylabel('y [Mpc/h]')
